# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
data = pd.read_csv(r"C:\.....\comprar_alquilar.csv")

# %%
#data.iloc[:,:24].plot(kind='box', subplots=True, layout=(12,12), sharex=False, sharey=False,figsize=(30,20)) #individual
x=data
x.iloc[:,:24].plot(kind='box', subplots=True, layout=(3,4), sharex=False, sharey=False,figsize=(20,20))
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn import preprocessing
scaler = MinMaxScaler()
data = scaler.fit_transform(data)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
ax=0
for i in range (9):

    fig = plt.figure(figsize=(15,5))   #  figure size (optional)

    plt.subplot(1,2,1)                #  subplot 1
    sns.histplot(data = data.iloc[:,i+1])

    plt.subplot(1,2,2)                #  subplot 2
    sns.boxplot(data= data.iloc[:,i+1])

    plt.show()                        #  draw subplot group

# %%
ax = x.hist(bins=25, grid=True, figsize=(12,12), color='#86bf91', zorder=3, rwidth=0.99)

# %%
#find the correlation betweeen the variables 
import seaborn as sns 

corr = x.corr() 
fig = plt.figure(figsize=(20,10))
sns.heatmap(corr, vmax=.8, square=True,annot=True)
# Out:
# <AxesSubplot:>

# %%
fig = plt.figure(figsize = (50,50))
ax = fig.gca()
x.plot(kind='bar',stacked=True,ax = ax)
# Out:
# <AxesSubplot:>
